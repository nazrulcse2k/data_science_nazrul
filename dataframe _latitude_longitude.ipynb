# %%
#import beautifulsoup
from bs4 import BeautifulSoup

# %%
#fetch html contents
import requests
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url).text
soup = BeautifulSoup(html_content, 'html.parser')
#print(soup.prettify())

# %%
#retrieve the table
address_table = soup.find("table", attrs={"class": "wikitable"})
address_table_data = address_table.tbody.find_all("tr")
#address_table_data

# %%
#retrieve the headers
#address_table_data[0]
headers_data = address_table_data[0].find_all("th")
headers_data
headers = []
for header in headers_data:
    headers.append(header.text.replace('\n', ' ').strip())

print(headers)
# Out:
# ['Postal Code', 'Borough', 'Neighborhood']

# %%
#data frame in panda
import pandas as pd
import numpy as np
# Get all the rows of table
table_data = []
for tr in address_table_data: # find all tr's from table's tbody
    #print(tr)
    cols = tr.find_all('td')
    cols = [td.text.replace('\n', '').strip() for td in cols]
    table_data.append([td for td in cols if td])

#table_data
df = pd.DataFrame(table_data, columns = headers)
#print(df)

# %%
# drop cells with 'Not assigned' in Borough
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df['Borough'].replace('None', np.nan, inplace=True)
df.dropna(subset=['Borough'], inplace=True)
#df.shape
l = len(df)
print(l)
# Out:
# 103

# %%
# get geolocation data
import geocoder # import geocoder

# %%
# initialize your variable to None
lat_lng_coords = None

# %%
# loop until you get the coordinates
#for i in range(len(df)):
#    postal_code = df['Postal Code'].iloc[i]
#    #print(postal_code)
#    while(lat_lng_coords is None):
#        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#        lat_lng_coords = g.latlng
    #df['Latitude'].iloc[i] = lat_lng_coords[0]
    #df['Longitude'].iloc[i] = lat_lng_coords[1]

#print(df)
df_geoloc = pd.read_csv("C:\\NecessaryFolders\\PYTHON_IBM_DATA_SCIENCE\\notebooks\\week3_assignment_submission\\Geospatial_Coordinates.csv")
df_geoloc
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df['Latitude'] = df_geoloc['Latitude']
df['Longitude'] = df_geoloc['Longitude']
df
# Out:
#     Postal Code           Borough  \
# 3           M3A        North York
# 4           M4A        North York
# 5           M5A  Downtown Toronto
# 6           M6A        North York
# 7           M7A  Downtown Toronto
# ..          ...               ...
# 161         M8X         Etobicoke
# 166         M4Y  Downtown Toronto
# 169         M7Y      East Toronto
# 170         M8Y         Etobicoke
# 179         M8Z         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 3                                            Parkwoods  43.770992 -79.216917
# 4                                     Victoria Village  43.773136 -79.239476
# 5                            Regent Park, Harbourfront  43.744734 -79.239476
# 6                     Lawrence Manor, Lawrence Heights  43.727929 -79.262029
# 7          Queen's Park, Ontario Provincial Government  43.711112 -79.284577
# ..                                                 ...        ...        ...
# 161      The Kingsway, Montgomery Road, Old Mill North        NaN        NaN
# 166                               Church and Wellesley        NaN        NaN
# 169              Business reply mail Processing Centre        NaN        NaN
# 170  Old Mill South, King's Mill Park, Sunnylea, Hu...        NaN        NaN
# 179  Mimico NW, The Queensway West, South of Bloor,...        NaN        NaN
#
# [103 rows x 5 columns]
